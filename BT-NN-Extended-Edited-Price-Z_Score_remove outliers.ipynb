# %% [markdown]
# # Project Predicting BitCoin Price  using historical data for 1 year

# %% [markdown]
# # By Ahmed Naser

# %% [markdown]
# # Importing Libraries:

# %%
#importing the libraries and the data csv file 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import scipy.stats as stats
import seaborn as sns
import math, time
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.layers import LSTM
import keras
import h5py
import requests
bt_df = pd.read_csv('bit_coin_ex.csv')
# understanding the data 
bt_df.head()
# Out:
#            Date  Price   Open   High    Low     Vol. Change %
# 0  Oct 16, 2015  262.9  254.4  267.3  253.9   95.18K    3.31%
# 1  Oct 17, 2015  269.6  262.9  275.4  261.7  113.84K    2.55%
# 2  Oct 18, 2015  261.7  269.6  272.4  259.5   52.27K   -2.93%
# 3  Oct 19, 2015  263.8  261.7  266.0  259.9   58.17K    0.82%
# 4  Oct 20, 2015  269.8  263.8  272.1  262.7   75.40K    2.25%

# %%
bt_df.describe()
# Out:
#                 Date  Price   Open   High    Low   Vol. Change %
# count           2193   2193   2193   2193   2193   2193     2193
# unique          2193   2158   2151   2149   2153   2084     1066
# top     Mar 11, 2016  891.1  423.5  612.4  592.8  1.05M   -0.50%
# freq               1      2      2      2      3      6       11

# %%
bt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2193 non-null   object
#  1   Price     2193 non-null   object
#  2   Open      2193 non-null   object
#  3   High      2193 non-null   object
#  4   Low       2193 non-null   object
#  5   Vol.      2193 non-null   object
#  6   Change %  2193 non-null   object
# dtypes: object(7)
# memory usage: 120.1+ KB

# %%
# converting the date to date time 
#cleaning the data
bt_df['Date'] =pd.to_datetime(bt_df['Date'], infer_datetime_format=True)

# %%
bt_df['Date']
# Out:
# 0      2015-10-16
# 1      2015-10-17
# 2      2015-10-18
# 3      2015-10-19
# 4      2015-10-20
#           ...
# 2188   2021-10-12
# 2189   2021-10-13
# 2190   2021-10-14
# 2191   2021-10-15
# 2192   2021-10-16
# Name: Date, Length: 2193, dtype: datetime64[ns]

# %%
bt_df.set_index('Date',inplace=True)

# %%
bt_df.head()
# Out:
#             Price   Open   High    Low     Vol. Change %
# Date
# 2015-10-16  262.9  254.4  267.3  253.9   95.18K    3.31%
# 2015-10-17  269.6  262.9  275.4  261.7  113.84K    2.55%
# 2015-10-18  261.7  269.6  272.4  259.5   52.27K   -2.93%
# 2015-10-19  263.8  261.7  266.0  259.9   58.17K    0.82%
# 2015-10-20  269.8  263.8  272.1  262.7   75.40K    2.25%

# %%
# checking the duplicates and nun values

sum(bt_df.duplicated())
# Out:
# 0

# %%
bt_df.isnull()
# Out:
#             Price   Open   High    Low   Vol.  Change %
# Date
# 2015-10-16  False  False  False  False  False     False
# 2015-10-17  False  False  False  False  False     False
# 2015-10-18  False  False  False  False  False     False
# 2015-10-19  False  False  False  False  False     False
# 2015-10-20  False  False  False  False  False     False
# ...           ...    ...    ...    ...    ...       ...
# 2021-10-12  False  False  False  False  False     False
# 2021-10-13  False  False  False  False  False     False
# 2021-10-14  False  False  False  False  False     False
# 2021-10-15  False  False  False  False  False     False
# 2021-10-16  False  False  False  False  False     False
#
# [2193 rows x 6 columns]

# %%
bt_df.isnull().sum()
# Out:
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
bt_df.head()
# Out:
#             Price   Open   High    Low     Vol. Change %
# Date
# 2015-10-16  262.9  254.4  267.3  253.9   95.18K    3.31%
# 2015-10-17  269.6  262.9  275.4  261.7  113.84K    2.55%
# 2015-10-18  261.7  269.6  272.4  259.5   52.27K   -2.93%
# 2015-10-19  263.8  261.7  266.0  259.9   58.17K    0.82%
# 2015-10-20  269.8  263.8  272.1  262.7   75.40K    2.25%

# %%
bt_df.dtypes
# converting data types
# Out:
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
bt_df['Change %'] = bt_df['Change %'].str.replace('%','').astype(float)

# %%
bt_df['Price'] = bt_df['Price'].str.replace(',','').astype(float)

# %%
bt_df['Open'] = bt_df['Open'].str.replace(',','').astype(float)

# %%
bt_df['High'] = bt_df['High'].str.replace(',','').astype(float)

# %%
bt_df['Low'] = bt_df['Low'].str.replace(',','').astype(float)

# %%
bt_df['Vol.']=bt_df['Vol.'].replace({'K': '*1e3', 'M': '*1e6'}, regex=True).map(pd.eval).astype(float)

# %%
bt_df['Vol.']
# Out:
# Date
# 2015-10-16     95180.0
# 2015-10-17    113840.0
# 2015-10-18     52270.0
# 2015-10-19     58170.0
# 2015-10-20     75400.0
#                 ...
# 2021-10-12     74850.0
# 2021-10-13     73620.0
# 2021-10-14     59840.0
# 2021-10-15    121480.0
# 2021-10-16     49930.0
# Name: Vol., Length: 2193, dtype: float64

# %%
bt_df.rename(columns={'Vol.': 'Vol'}, inplace=True)

# %%
bt_df.head()
# Out:
#             Price   Open   High    Low       Vol  Change %
# Date
# 2015-10-16  262.9  254.4  267.3  253.9   95180.0      3.31
# 2015-10-17  269.6  262.9  275.4  261.7  113840.0      2.55
# 2015-10-18  261.7  269.6  272.4  259.5   52270.0     -2.93
# 2015-10-19  263.8  261.7  266.0  259.9   58170.0      0.82
# 2015-10-20  269.8  263.8  272.1  262.7   75400.0      2.25

# %%
bt_df.describe()
#  getting describtive statitics for data analysis  
#as we see the values for the Vol K NEEDS TO BE CHECKED
# Out:
#               Price          Open  ...           Vol     Change %
# count   2193.000000   2193.000000  ...  2.193000e+03  2193.000000
# mean   11049.915002  11022.382809  ...  5.079180e+05     0.332088
# std    14372.323846  14334.893312  ...  1.298619e+06     4.028708
# min      261.700000    254.400000  ...  2.600000e+02   -39.180000
# 25%     1248.200000   1243.100000  ...  7.098000e+04    -1.250000
# 50%     6867.800000   6862.700000  ...  1.420700e+05     0.230000
# 75%    10473.000000  10470.100000  ...  5.099400e+05     1.980000
# max    63540.900000  63544.200000  ...  2.026000e+07    25.560000
#
# [8 rows x 6 columns]

# %%
bt_df[bt_df['Price'] == bt_df['Price'].min()]
#THE LOWEST Price VALUE
# Out:
#             Price   Open   High    Low      Vol  Change %
# Date
# 2015-10-18  261.7  269.6  272.4  259.5  52270.0     -2.93

# %%
bt_df[bt_df['Price'] == bt_df['Price'].max()]
#The highest price Value
# Out:
#               Price     Open     High      Low       Vol  Change %
# Date
# 2021-04-13  63540.9  59863.6  63659.0  59839.4  126560.0      6.14

# %%
bt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2193 entries, 2015-10-16 to 2021-10-16
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     2193 non-null   float64
#  1   Open      2193 non-null   float64
#  2   High      2193 non-null   float64
#  3   Low       2193 non-null   float64
#  4   Vol       2193 non-null   float64
#  5   Change %  2193 non-null   float64
# dtypes: float64(6)
# memory usage: 119.9 KB

# %%
bt_df.head(30)
# we find  Noticeable increase in recent days for the price
# Out:
#             Price   Open   High    Low       Vol  Change %
# Date
# 2015-10-16  262.9  254.4  267.3  253.9   95180.0      3.31
# 2015-10-17  269.6  262.9  275.4  261.7  113840.0      2.55
# 2015-10-18  261.7  269.6  272.4  259.5   52270.0     -2.93
# 2015-10-19  263.8  261.7  266.0  259.9   58170.0      0.82
# 2015-10-20  269.8  263.8  272.1  262.7   75400.0      2.25
# 2015-10-21  267.1  269.8  272.2  263.5   59640.0     -0.98
# 2015-10-22  274.4  267.1  278.7  266.8   93150.0      2.74
# 2015-10-23  276.9  274.4  279.8  273.2   69320.0      0.91
# 2015-10-24  282.6  276.9  283.0  277.0   60130.0      2.04
# 2015-10-25  287.9  282.6  295.6  281.8  113900.0      1.88
# 2015-10-26  285.1  287.9  287.6  279.6   73210.0     -0.94
# 2015-10-27  294.7  285.1  298.4  285.1  105870.0      3.34
# 2015-10-28  303.5  294.7  307.5  294.0  116410.0      3.01
# 2015-10-29  313.6  303.5  318.5  300.2  138920.0      3.32
# 2015-10-30  327.1  313.6  334.9  310.8  156490.0      4.30
# 2015-10-31  311.2  327.1  333.3  304.6  105830.0     -4.85
# 2015-11-01  323.0  311.2  324.3  304.7   73710.0      3.76
# 2015-11-02  359.3  323.0  365.8  319.8  223100.0     11.25
# 2015-11-03  396.5  359.3  416.8  354.6  421990.0     10.36
# 2015-11-04  400.9  396.5  492.8  368.6  517730.0      1.11
# 2015-11-05  382.7  400.9  447.2  366.1  302950.0     -4.54
# 2015-11-06  369.8  382.7  396.4  348.8  255280.0     -3.37
# 2015-11-07  385.1  369.8  391.8  369.0  103030.0      4.13
# 2015-11-08  371.6  385.1  389.8  365.5   94360.0     -3.51
# 2015-11-09  380.2  371.6  385.1  360.2  125540.0      2.33
# 2015-11-10  336.7  380.2  381.4  323.2  210290.0    -11.45
# 2015-11-11  304.7  336.7  341.8  292.4  263960.0     -9.50
# 2015-11-12  333.9  304.7  346.1  306.1  164610.0      9.56
# 2015-11-13  333.8  333.9  341.8  323.9   97250.0     -0.02
# 2015-11-14  331.8  333.8  369.8  326.4   71110.0     -0.60

# %%
sns.pairplot(bt_df)

# %%
bt_df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f195a761dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1960fd7390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1961176350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f195e8deb90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f195ea6efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f195e9b7f50>]],
#       dtype=object)

# %%
plt.figure(figsize=(15,7))
sns.heatmap(bt_df.corr(), annot=True)

# %%
bt_df['Price'].plot(figsize=(10,10))

# %%
bt_df['Vol'].plot(kind='box',figsize=(10,10));
# As we see with Vol K box plot 
#we have outliers that i think its the reason for the skewness of the distribution

# %%
bt_df.plot(kind= 'box', figsize=(10,10))
# check the data correlations , normalization , sizes and outliers

# %%
bt_df['Change %'].plot(kind='box',figsize=(10,10));
# AS we see the outliers here in Change % 
# but the distribution is approximately normal and the outliers doest effect that much

# %%
bt_df['Price'].plot(kind='box');

# its really good a clear strong Positive correlation here

# %%
bt_df['High'].plot(kind='box');

# %%
bt_df['Low'].plot(kind='box');
# we cant see a clear correlation here

# %%
bt_df['Open'].plot(kind='box');

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 17))
fig.suptitle('Outliers', fontsize=25)

ax=sns.boxplot(ax=axes[0,0], data=bt_df['Price'])
ax.set_title('Price')
ax=sns.boxplot(ax=axes[0,1], data=bt_df['Open'])
ax.set_title('Open')
ax=sns.boxplot(ax=axes[0,2], data=bt_df['High'])
ax.set_title('High')
ax=sns.boxplot(ax=axes[1,0], data=bt_df['Low'])
ax.set_title('Low')
ax=sns.boxplot(ax=axes[1,1], data=bt_df['Vol'])
ax.set_title('Volume')
ax=sns.boxplot(ax=axes[1,2], data=bt_df['Change %'])
ax.set_title('Change %')
# Out:
# Text(0.5, 1.0, 'Change %')

# %%
bt_df.agg(['skew', 'kurtosis']).transpose()
# Vol K highly skewed to right 
# vol k skewnes is more that 1.
# Out:
#               skew   kurtosis
# Price     2.019588   3.115004
# Open      2.021898   3.128203
# High      2.011661   3.059617
# Low       2.034225   3.208467
# Vol       7.445426  71.592031
# Change % -0.183177   7.448397

# %%
Q1 = np.percentile(bt_df['Vol'], 25, interpolation = 'midpoint')
Q3 = np.percentile(bt_df['Vol'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1

print("Upper bound:",(Q3+1.5*IQR))
print("Lower bound:", (Q1-1.5*IQR))
upper_vol=(Q3 + 1.5 * IQR)
lower_vol=(Q1 - 1.5 * IQR)
print("Number of Outliers:", ((bt_df['Vol'] < (Q1 - 1.5 * IQR)) | (bt_df['Vol'] > (Q3 + 1.5 * IQR))).sum() )
# Out:
# Upper bound: 1168380.0
# Lower bound: -587460.0
# Number of Outliers: 160

# %%
Q1= np.percentile(bt_df['Change %'], 25, interpolation = 'midpoint')
Q3 = np.percentile(bt_df['Change %'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
upper_change=(Q3 + 1.5 * IQR)
lower_change=(Q1 - 1.5 * IQR)
print("Upper bound:",(Q3+1.5*IQR))
print("Lower bound:", (Q1-1.5*IQR))
upper_change=(Q3 + 1.5 * IQR)
lower_change=(Q1 - 1.5 * IQR)
print("Number of Outliers:", ((bt_df['Change %'] < (Q1 - 1.5 * IQR)) | (bt_df['Change %'] > (Q3 + 1.5 * IQR))).sum() )
# Out:
# Upper bound: 6.824999999999999
# Lower bound: -6.095
# Number of Outliers: 229

# %%
Q1= np.percentile(bt_df['Price'], 25, interpolation = 'midpoint')
Q3 = np.percentile(bt_df['Price'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1

print("Upper bound:",(Q3+1.5*IQR))
print("Lower bound:", (Q1-1.5*IQR))
upper_price = (Q3 + 1.5 * IQR)
lower_price = (Q1 - 1.5 * IQR)
print("Number of Outliers:", ((bt_df['Price'] < (Q1 - 1.5 * IQR)) | (bt_df['Price'] > (Q3 + 1.5 * IQR))).sum() )
# Out:
# Upper bound: 24310.199999999997
# Lower bound: -12588.999999999998
# Number of Outliers: 296

# %%
Q1= np.percentile(bt_df['Open'], 25, interpolation = 'midpoint')
Q3 = np.percentile(bt_df['Open'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1

print("Upper bound:",(Q3+1.5*IQR))
print("Lower bound:", (Q1-1.5*IQR))
upper_open=(Q3 + 1.5 * IQR)
lower_open=(Q1 - 1.5 * IQR)
print("Number of Outliers:", ((bt_df['Open'] < (Q1 - 1.5 * IQR)) | (bt_df['Open'] > (Q3 + 1.5 * IQR))).sum() )
# Out:
# Upper bound: 24310.6
# Lower bound: -12597.4
# Number of Outliers: 295

# %%
Q1= np.percentile(bt_df['High'], 25, interpolation = 'midpoint')
Q3 = np.percentile(bt_df['High'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1

print("Upper bound:",(Q3+1.5*IQR))
print("Lower bound:", (Q1-1.5*IQR))
upper_high=(Q3 + 1.5 * IQR)
lower_high=(Q1 - 1.5 * IQR)
print("Number of Outliers:", ((bt_df['High'] < (Q1 - 1.5 * IQR)) | (bt_df['High'] > (Q3 + 1.5 * IQR))).sum() )
# Out:
# Upper bound: 25088.5
# Lower bound: -13041.900000000001
# Number of Outliers: 295

# %%
Q1= np.percentile(bt_df['Low'], 25, interpolation = 'midpoint')
Q3 = np.percentile(bt_df['Low'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1

print("Upper bound:",(Q3+1.5*IQR))
print("Lower bound:", (Q1-1.5*IQR))
upper_low=(Q3 + 1.5 * IQR)
lower_low=(Q1 - 1.5 * IQR)
print("Number of Outliers:", ((bt_df['Low'] < (Q1 - 1.5 * IQR)) | (bt_df['Low'] > (Q3 + 1.5 * IQR))).sum() )
# Out:
# Upper bound: 23574.15
# Lower bound: -12195.050000000001
# Number of Outliers: 295

# %%
z_scores = stats.zscore(bt_df)

abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
new_df = bt_df[filtered_entries]

print(new_df)
# Out:
#               Price     Open     High      Low       Vol  Change %
# Date
# 2015-10-16    262.9    254.4    267.3    253.9   95180.0      3.31
# 2015-10-17    269.6    262.9    275.4    261.7  113840.0      2.55
# 2015-10-18    261.7    269.6    272.4    259.5   52270.0     -2.93
# 2015-10-19    263.8    261.7    266.0    259.9   58170.0      0.82
# 2015-10-20    269.8    263.8    272.1    262.7   75400.0      2.25
# ...             ...      ...      ...      ...       ...       ...
# 2021-10-01  48146.0  43824.4  48435.2  43292.9   94660.0      9.86
# 2021-10-02  47666.9  48147.2  48306.9  47451.7   39820.0     -1.00
# 2021-10-03  48200.1  47665.4  49165.2  47123.0   42410.0      1.12
# 2021-10-04  49227.3  48200.4  49481.7  46958.6   66920.0      2.13
# 2021-10-05  51469.3  49229.5  51872.4  49060.1   76630.0      4.55
#
# [2058 rows x 6 columns]

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 17))
fig.suptitle('Outliers', fontsize=25)

ax=sns.boxplot(ax=axes[0,0], data=new_df['Price'])
ax.set_title('Price')
ax=sns.boxplot(ax=axes[0,1], data=new_df['Open'])
ax.set_title('Open')
ax=sns.boxplot(ax=axes[0,2], data=new_df['High'])
ax.set_title('High')
ax=sns.boxplot(ax=axes[1,0], data=new_df['Low'])
ax.set_title('Low')
ax=sns.boxplot(ax=axes[1,1], data=new_df['Vol'])
ax.set_title('Volume')
ax=sns.boxplot(ax=axes[1,2], data=new_df['Change %'])
ax.set_title('Change %')
# Out:
# Text(0.5, 1.0, 'Change %')

# %%
new_df.agg(['skew', 'kurtosis']).transpose()
# Out:
#               skew   kurtosis
# Price     2.119380   3.808947
# Open      2.121738   3.825358
# High      2.118287   3.779055
# Low       2.125161   3.872762
# Vol       3.400032  13.348052
# Change %  0.072067   1.571529

# %%
new_df['Change %'].plot()

# %%
new_df['Price'].plot()

# %%
new_df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f195a249050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f195a280550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f195a236950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f195a1ece50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f195a1ad390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f195a162890>]],
#       dtype=object)

# %%
cor_matrix = new_df.corr().abs()
print(cor_matrix)
# Out:
#              Price      Open      High       Low       Vol  Change %
# Price     1.000000  0.998662  0.999455  0.999242  0.076966  0.029671
# Open      0.998662  1.000000  0.999332  0.999025  0.076801  0.005258
# High      0.999455  0.999332  1.000000  0.998860  0.076861  0.014403
# Low       0.999242  0.999025  0.998860  1.000000  0.076331  0.014515
# Vol       0.076966  0.076801  0.076861  0.076331  1.000000  0.008443
# Change %  0.029671  0.005258  0.014403  0.014515  0.008443  1.000000

# %%
new_df.head()
# Out:
#             Price   Open   High    Low       Vol  Change %
# Date
# 2015-10-16  262.9  254.4  267.3  253.9   95180.0      3.31
# 2015-10-17  269.6  262.9  275.4  261.7  113840.0      2.55
# 2015-10-18  261.7  269.6  272.4  259.5   52270.0     -2.93
# 2015-10-19  263.8  261.7  266.0  259.9   58170.0      0.82
# 2015-10-20  269.8  263.8  272.1  262.7   75400.0      2.25

# %%
def plot_data(new_df,feature):
    plt.figure(figsize=(8,8))
    plt.subplot(1,2,1)
    new_df[feature].hist()
    plt.subplot(1,2,2)
    stats.probplot(new_df[feature],dist='norm',plot=plt)
    plt.show()

# %%
plot_data(new_df,'Vol')

# %%
plot_data(new_df,'Change %')
plot_data(new_df,'Open')
plot_data(new_df,'Price')
#Change is probability plot

# %%
plt.plot(new_df['Change %'])
plt.show()

# %%
plt.plot(new_df['Price'])
plt.show()

# %%
new_df.head()
# Out:
#             Price   Open   High    Low       Vol  Change %
# Date
# 2015-10-16  262.9  254.4  267.3  253.9   95180.0      3.31
# 2015-10-17  269.6  262.9  275.4  261.7  113840.0      2.55
# 2015-10-18  261.7  269.6  272.4  259.5   52270.0     -2.93
# 2015-10-19  263.8  261.7  266.0  259.9   58170.0      0.82
# 2015-10-20  269.8  263.8  272.1  262.7   75400.0      2.25

# %%
df=new_df.reset_index()['Price']
df
# Out:
# 0         262.9
# 1         269.6
# 2         261.7
# 3         263.8
# 4         269.8
#          ...
# 2053    48146.0
# 2054    47666.9
# 2055    48200.1
# 2056    49227.3
# 2057    51469.3
# Name: Price, Length: 2058, dtype: float64

# %%
len(df)
# Out:
# 2058

# %%
plt.plot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
minmax=MinMaxScaler(feature_range=(0,1))
df = minmax.fit_transform(np.array(df).reshape(-1,1))

# %%
training_size=int(len(df)*.65)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]
training_size,test_size
# Out:
# (1337, 721)

# %%
len(train_data)+len(test_data)
# Out:
# 2058

# %%
def create_dataset(dataset, time_step=20):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step=20
x_train, y_train = create_dataset(train_data, time_step)
x_test, y_test = create_dataset(test_data, time_step)

# %%
x_train
# Out:
# array([[2.23219268e-05, 1.46952685e-04, 0.00000000e+00, ...,
#         1.81551672e-03, 2.50749645e-03, 2.58934351e-03],
#        [1.46952685e-04, 0.00000000e+00, 3.90633720e-05, ...,
#         2.50749645e-03, 2.58934351e-03, 2.25079429e-03],
#        [0.00000000e+00, 3.90633720e-05, 1.50673006e-04, ...,
#         2.58934351e-03, 2.25079429e-03, 2.01083358e-03],
#        ...,
#        [2.16505949e-01, 2.02783544e-01, 1.99195295e-01, ...,
#         1.94437004e-01, 1.88821179e-01, 1.79077658e-01],
#        [2.02783544e-01, 1.99195295e-01, 2.04734853e-01, ...,
#         1.88821179e-01, 1.79077658e-01, 1.77507682e-01],
#        [1.99195295e-01, 2.04734853e-01, 2.07486030e-01, ...,
#         1.79077658e-01, 1.77507682e-01, 1.80130509e-01]])

# %%
print(x_train.shape), print(y_train.shape)
# Out:
# (1316, 20)
# (1316,)
# (None, None)

# %%
print(x_test.shape), print(y_test.shape)
# Out:
# (700, 20)
# (700,)
# (None, None)

# %%
# reshaping the input [sample ,time steps ,features ] For LSTM
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test =x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
# creating the model 
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(20,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 20, 50)            10400
#
#  lstm_22 (LSTM)              (None, 20, 50)            20200
#
#  lstm_23 (LSTM)              (None, 50)                20200
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 7s 103ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 2/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.2961e-04 - val_loss: 0.0064
# Epoch 3/100
# 21/21 [==============================] - 1s 43ms/step - loss: 3.3611e-04 - val_loss: 0.0080
# Epoch 4/100
# 21/21 [==============================] - 1s 43ms/step - loss: 3.2150e-04 - val_loss: 0.0075
# Epoch 5/100
# 21/21 [==============================] - 1s 43ms/step - loss: 2.9244e-04 - val_loss: 0.0079
# Epoch 6/100
# 21/21 [==============================] - 1s 42ms/step - loss: 3.0154e-04 - val_loss: 0.0093
# Epoch 7/100
# 21/21 [==============================] - 1s 44ms/step - loss: 2.7072e-04 - val_loss: 0.0128
# Epoch 8/100
# 21/21 [==============================] - 1s 43ms/step - loss: 2.4743e-04 - val_loss: 0.0123
# Epoch 9/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.1534e-04 - val_loss: 0.0143
# Epoch 10/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.9649e-04 - val_loss: 0.0176
# Epoch 11/100
# 21/21 [==============================] - 1s 42ms/step - loss: 2.0251e-04 - val_loss: 0.0167
# Epoch 12/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.9587e-04 - val_loss: 0.0121
# Epoch 13/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.7174e-04 - val_loss: 0.0124
# Epoch 14/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.6928e-04 - val_loss: 0.0181
# Epoch 15/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.6744e-04 - val_loss: 0.0102
# Epoch 16/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.6267e-04 - val_loss: 0.0078
# Epoch 17/100
# 21/21 [==============================] - 1s 44ms/step - loss: 1.5132e-04 - val_loss: 0.0104
# Epoch 18/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.4716e-04 - val_loss: 0.0100
# Epoch 19/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.4226e-04 - val_loss: 0.0101
# Epoch 20/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.4340e-04 - val_loss: 0.0127
# Epoch 21/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.5589e-04 - val_loss: 0.0061
# Epoch 22/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.3940e-04 - val_loss: 0.0088
# Epoch 23/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.3479e-04 - val_loss: 0.0082
# Epoch 24/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.2225e-04 - val_loss: 0.0092
# Epoch 25/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.2019e-04 - val_loss: 0.0048
# Epoch 26/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.3094e-04 - val_loss: 0.0063
# Epoch 27/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.2300e-04 - val_loss: 0.0068
# Epoch 28/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.2561e-04 - val_loss: 0.0068
# Epoch 29/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.1464e-04 - val_loss: 0.0075
# Epoch 30/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.1138e-04 - val_loss: 0.0059
# Epoch 31/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.0509e-04 - val_loss: 0.0056
# Epoch 32/100
# 21/21 [==============================] - 1s 43ms/step - loss: 9.7987e-05 - val_loss: 0.0045
# Epoch 33/100
# 21/21 [==============================] - 1s 42ms/step - loss: 9.2697e-05 - val_loss: 0.0029
# Epoch 34/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.0068e-04 - val_loss: 0.0033
# Epoch 35/100
# 21/21 [==============================] - 1s 43ms/step - loss: 9.6309e-05 - val_loss: 0.0050
# Epoch 36/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.0029e-04 - val_loss: 0.0039
# Epoch 37/100
# 21/21 [==============================] - 1s 42ms/step - loss: 8.6703e-05 - val_loss: 0.0040
# Epoch 38/100
# 21/21 [==============================] - 1s 41ms/step - loss: 9.4685e-05 - val_loss: 0.0029
# Epoch 39/100
# 21/21 [==============================] - 1s 42ms/step - loss: 8.7970e-05 - val_loss: 0.0049
# Epoch 40/100
# 21/21 [==============================] - 1s 43ms/step - loss: 8.3250e-05 - val_loss: 0.0053
# Epoch 41/100
# 21/21 [==============================] - 1s 43ms/step - loss: 9.2855e-05 - val_loss: 0.0024
# Epoch 42/100
# 21/21 [==============================] - 1s 43ms/step - loss: 7.8947e-05 - val_loss: 0.0052
# Epoch 43/100
# 21/21 [==============================] - 1s 42ms/step - loss: 8.0244e-05 - val_loss: 0.0040
# Epoch 44/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.9929e-05 - val_loss: 0.0034
# Epoch 45/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.6263e-05 - val_loss: 0.0047
# Epoch 46/100
# 21/21 [==============================] - 1s 42ms/step - loss: 8.0465e-05 - val_loss: 0.0039
# Epoch 47/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.6070e-05 - val_loss: 0.0046
# Epoch 48/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.2602e-05 - val_loss: 0.0030
# Epoch 49/100
# 21/21 [==============================] - 1s 44ms/step - loss: 7.0702e-05 - val_loss: 0.0026
# Epoch 50/100
# 21/21 [==============================] - 1s 42ms/step - loss: 6.9551e-05 - val_loss: 0.0051
# Epoch 51/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.2449e-05 - val_loss: 0.0030
# Epoch 52/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.7558e-05 - val_loss: 0.0056
# Epoch 53/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.5749e-05 - val_loss: 0.0029
# Epoch 54/100
# 21/21 [==============================] - 1s 43ms/step - loss: 7.3346e-05 - val_loss: 0.0023
# Epoch 55/100
# 21/21 [==============================] - 1s 42ms/step - loss: 7.1088e-05 - val_loss: 0.0025
# Epoch 56/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.5095e-05 - val_loss: 0.0035
# Epoch 57/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.8630e-05 - val_loss: 0.0018
# Epoch 58/100
# 21/21 [==============================] - 1s 43ms/step - loss: 8.3389e-05 - val_loss: 0.0035
# Epoch 59/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.2365e-05 - val_loss: 0.0029
# Epoch 60/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.3359e-05 - val_loss: 0.0018
# Epoch 61/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.4953e-05 - val_loss: 0.0032
# Epoch 62/100
# 21/21 [==============================] - 1s 42ms/step - loss: 5.9636e-05 - val_loss: 0.0030
# Epoch 63/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.8415e-05 - val_loss: 0.0023
# Epoch 64/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.2365e-05 - val_loss: 0.0018
# Epoch 65/100
# 21/21 [==============================] - 1s 41ms/step - loss: 6.0939e-05 - val_loss: 0.0017
# Epoch 66/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.7580e-05 - val_loss: 0.0017
# Epoch 67/100
# 21/21 [==============================] - 1s 42ms/step - loss: 6.5182e-05 - val_loss: 0.0025
# Epoch 68/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.6477e-05 - val_loss: 6.5302e-04
# Epoch 69/100
# 21/21 [==============================] - 1s 42ms/step - loss: 6.3523e-05 - val_loss: 0.0023
# Epoch 70/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.7420e-05 - val_loss: 0.0015
# Epoch 71/100
# 21/21 [==============================] - 1s 42ms/step - loss: 5.7395e-05 - val_loss: 0.0018
# Epoch 72/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.4128e-05 - val_loss: 0.0017
# Epoch 73/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.6173e-05 - val_loss: 0.0023
# Epoch 74/100
# 21/21 [==============================] - 1s 42ms/step - loss: 5.3867e-05 - val_loss: 0.0012
# Epoch 75/100
# 21/21 [==============================] - 1s 42ms/step - loss: 6.0809e-05 - val_loss: 0.0011
# Epoch 76/100
# 21/21 [==============================] - 1s 42ms/step - loss: 5.4747e-05 - val_loss: 0.0019
# Epoch 77/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.2756e-05 - val_loss: 6.1192e-04
# Epoch 78/100
# 21/21 [==============================] - 1s 41ms/step - loss: 5.5539e-05 - val_loss: 0.0015
# Epoch 79/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.2573e-05 - val_loss: 9.1993e-04
# Epoch 80/100
# 21/21 [==============================] - 1s 42ms/step - loss: 5.6801e-05 - val_loss: 0.0013
# Epoch 81/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.1328e-05 - val_loss: 9.7550e-04
# Epoch 82/100
# 21/21 [==============================] - 1s 42ms/step - loss: 4.9514e-05 - val_loss: 0.0013
# Epoch 83/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.6334e-05 - val_loss: 9.8404e-04
# Epoch 84/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.2650e-05 - val_loss: 4.9239e-04
# Epoch 85/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.6413e-05 - val_loss: 0.0017
# Epoch 86/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.4886e-05 - val_loss: 5.9849e-04
# Epoch 87/100
# 21/21 [==============================] - 1s 42ms/step - loss: 6.6663e-05 - val_loss: 9.2070e-04
# Epoch 88/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.6744e-05 - val_loss: 5.6424e-04
# Epoch 89/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.5059e-05 - val_loss: 7.7504e-04
# Epoch 90/100
# 21/21 [==============================] - 1s 42ms/step - loss: 5.3446e-05 - val_loss: 0.0010
# Epoch 91/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.3760e-05 - val_loss: 7.2739e-04
# Epoch 92/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.6927e-05 - val_loss: 8.0588e-04
# Epoch 93/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.3071e-05 - val_loss: 0.0017
# Epoch 94/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.6326e-05 - val_loss: 0.0011
# Epoch 95/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.4074e-05 - val_loss: 7.3603e-04
# Epoch 96/100
# 21/21 [==============================] - 1s 42ms/step - loss: 4.8946e-05 - val_loss: 0.0017
# Epoch 97/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.2637e-05 - val_loss: 5.3085e-04
# Epoch 98/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.3080e-05 - val_loss: 0.0014
# Epoch 99/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.3291e-05 - val_loss: 0.0010
# Epoch 100/100
# 21/21 [==============================] - 1s 43ms/step - loss: 3.7635e-05 - val_loss: 6.8725e-04

# %%
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# %%
train_predict=minmax.inverse_transform(train_predict)
test_predict=minmax.inverse_transform(test_predict)

# %%
from sklearn.metrics import mean_squared_error

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 5722.645492159514

# %%
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 23751.57398036129

# %%
time_step=20
plt.figure(figsize=(15,7))
trainpredictplot=np.empty_like(df)
trainpredictplot[:, :]=np.nan
trainpredictplot[time_step:len(train_predict)+time_step, :] = train_predict
testpredictplot=np.empty_like(df)
testpredictplot[:, :]=np.nan
testpredictplot[len(train_predict)+(time_step*2)+1:len(df)-1, :] = test_predict
plt.plot(minmax.inverse_transform(df))
plt.plot(trainpredictplot)
plt.plot(testpredictplot)
plt.show()

# %%
len(test_data)
# Out:
# 721

# %%
input_data=test_data[701:].reshape(1,-1)
input_data.shape
# Out:
# (1, 20)

# %%
price_input=list(input_data)
price_input=price_input[0].tolist()
price_input
# Out:
# [0.8833214283056914,
#  0.8746679613384228,
#  0.8937141454050314,
#  0.8738476305274672,
#  0.7925939567103433,
#  0.7513114132011877,
#  0.805261650185644,
#  0.8297711258435828,
#  0.7916508553018298,
#  0.7891749815844105,
#  0.7987845710841761,
#  0.7796100359383022,
#  0.7582126089124014,
#  0.7677831350402168,
#  0.810315706451781,
#  0.8907248673705515,
#  0.8818128380841835,
#  0.8917312142384131,
#  0.9108387836038008,
#  0.9525435835621332]

# %%
first_output=[]
n_step=20
i=0
while(i<11):
     if(len(price_input)>n_step):
        input_data=np.array(price_input[1:])
        print(' {} day input {} '.format(i,input_data))
        input_data=input_data.reshape(1,-1)
        input_data=input_data.reshape((1,n_step,1))
        y_new=model.predict(input_data,verbose=0)
        print('{} day output {}'.format(i,y_new))
        price_input.extend(y_new[0].tolist())
        price_input=price_input[1:]
        first_output.extend(y_new.tolist())
        i=i+1 
     else:
        input_data=input_data.reshape((1,n_step,1))
        y_new=model.predict(input_data,verbose=0)
        print(y_new[0])
        price_input.extend(y_new[0].tolist())
        print(len(price_input))
        first_output.extend(y_new.tolist())
        i=i+1

print(first_output)
# Out:
# [0.9250276]
# 21
#  1 day input [0.87466796 0.89371415 0.87384763 0.79259396 0.75131141 0.80526165
#  0.82977113 0.79165086 0.78917498 0.79878457 0.77961004 0.75821261
#  0.76778314 0.81031571 0.89072487 0.88181284 0.89173121 0.91083878
#  0.95254358 0.92502761]
# 1 day output [[0.8715448]]
#  2 day input [0.89371415 0.87384763 0.79259396 0.75131141 0.80526165 0.82977113
#  0.79165086 0.78917498 0.79878457 0.77961004 0.75821261 0.76778314
#  0.81031571 0.89072487 0.88181284 0.89173121 0.91083878 0.95254358
#  0.92502761 0.87154478]
# 2 day output [[0.8024067]]
#  3 day input [0.87384763 0.79259396 0.75131141 0.80526165 0.82977113 0.79165086
#  0.78917498 0.79878457 0.77961004 0.75821261 0.76778314 0.81031571
#  0.89072487 0.88181284 0.89173121 0.91083878 0.95254358 0.92502761
#  0.87154478 0.80240673]
# 3 day output [[0.73971784]]
#  4 day input [0.79259396 0.75131141 0.80526165 0.82977113 0.79165086 0.78917498
#  0.79878457 0.77961004 0.75821261 0.76778314 0.81031571 0.89072487
#  0.88181284 0.89173121 0.91083878 0.95254358 0.92502761 0.87154478
#  0.80240673 0.73971784]
# 4 day output [[0.6947848]]
#  5 day input [0.75131141 0.80526165 0.82977113 0.79165086 0.78917498 0.79878457
#  0.77961004 0.75821261 0.76778314 0.81031571 0.89072487 0.88181284
#  0.89173121 0.91083878 0.95254358 0.92502761 0.87154478 0.80240673
#  0.73971784 0.69478482]
# 5 day output [[0.66802764]]
#  6 day input [0.80526165 0.82977113 0.79165086 0.78917498 0.79878457 0.77961004
#  0.75821261 0.76778314 0.81031571 0.89072487 0.88181284 0.89173121
#  0.91083878 0.95254358 0.92502761 0.87154478 0.80240673 0.73971784
#  0.69478482 0.66802764]
# 6 day output [[0.6527826]]
#  7 day input [0.82977113 0.79165086 0.78917498 0.79878457 0.77961004 0.75821261
#  0.76778314 0.81031571 0.89072487 0.88181284 0.89173121 0.91083878
#  0.95254358 0.92502761 0.87154478 0.80240673 0.73971784 0.69478482
#  0.66802764 0.65278262]
# 7 day output [[0.6408615]]
#  8 day input [0.79165086 0.78917498 0.79878457 0.77961004 0.75821261 0.76778314
#  0.81031571 0.89072487 0.88181284 0.89173121 0.91083878 0.95254358
#  0.92502761 0.87154478 0.80240673 0.73971784 0.69478482 0.66802764
#  0.65278262 0.64086151]
# 8 day output [[0.6262885]]
#  9 day input [0.78917498 0.79878457 0.77961004 0.75821261 0.76778314 0.81031571
#  0.89072487 0.88181284 0.89173121 0.91083878 0.95254358 0.92502761
#  0.87154478 0.80240673 0.73971784 0.69478482 0.66802764 0.65278262
#  0.64086151 0.62628847]
# 9 day output [[0.6065458]]
#  10 day input [0.79878457 0.77961004 0.75821261 0.76778314 0.81031571 0.89072487
#  0.88181284 0.89173121 0.91083878 0.95254358 0.92502761 0.87154478
#  0.80240673 0.73971784 0.69478482 0.66802764 0.65278262 0.64086151
#  0.62628847 0.60654581]
# 10 day output [[0.582149]]
# [[0.92502760887146], [0.8715447783470154], [0.8024067282676697], [0.7397178411483765], [0.6947848200798035], [0.6680276393890381], [0.6527826189994812], [0.6408615112304688], [0.6262884736061096], [0.6065458059310913], [0.5821490287780762]]

# %%
newday=np.arange(1,n_step+1)
predicted_days=np.arange(n_step+1,n_step+12)

# %%
len(df)
# Out:
# 2058

# %%
df_new=df.tolist()
df_new.extend(first_output)

# %%
plt.plot(newday,minmax.inverse_transform(df[2038:]))
plt.plot(predicted_days,minmax.inverse_transform(first_output))

# %%
plt.figure(figsize=(15,8))
df=df.tolist()
df.extend(first_output)
plt.plot(df[2038:])

# %%
plt.figure(figsize=(15,7))
df=minmax.inverse_transform(df).tolist()
plt.plot(df)
